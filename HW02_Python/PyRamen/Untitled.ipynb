# %%
import pandas as pd
from pathlib import Path

# %%
menu_data_path = Path("C:\\Users\\vinot\\Fintech_Homeworks\\HW02_Python\\PyRamen\\menu_data.csv")
sales_data_path = Path("C:\\Users\\vinot\\Fintech_Homeworks\\HW02_Python\\PyRamen\\sales_data.csv")

# %%
menu_data =pd.read_csv(menu_data_path)
menu_data.columns
# Out:
# Index(['item', 'category', 'description', 'price', 'cost'], dtype='object')

# %%
upd_menu_data = pd.read_csv("menu_data.csv",names=["item","category","description","price","cost"])
upd_menu_data.head()
# Out:
#                            item    category  \
# 0                          item    category
# 1                       edamame  appetizers
# 2                   house salad  appetizers
# 3       cucumber sunomono salad  appetizers
# 4  hiyashi wakame seaweed salad  appetizers
#
#                                          description  price  cost
# 0                                        description  price  cost
# 1                   boiled soybeans, maldon sea salt      4     1
# 2  mixed greens, cherry tomatoes, cucumber, house...      4     2
# 3  cucumber, ponzu dressing, pickled ginger sprou...      5     2
# 4  sweet soy-marinated wakame seaweed threads, pi...      5     2

# %%
sales_data =pd.read_csv(sales_data_path)
sales_data.columns
# Out:
# Index(['Line_Item_ID', 'Date', 'Credit_Card_Number', 'Quantity', 'Menu_Item'], dtype='object')

# %%
upd_sales_data = pd.read_csv("sales_data.csv",names=['Line_Item_ID', 'Date', 'Credit_Card_Number', 'Quantity', 'Menu_Item'])
upd_sales_data.head()
# Out:
#    Line_Item_ID        Date  Credit_Card_Number  Quantity          Menu_Item
# 0  Line_Item_ID        Date  Credit_Card_Number  Quantity          Menu_Item
# 1             1  01-01-2017    7437926611570799         1   spicy miso ramen
# 2             2  01-01-2017    7437926611570799         1   spicy miso ramen
# 3             3  01-01-2017    8421920068932819         3  tori paitan ramen
# 4             4  01-01-2017    8421920068932819         3  tori paitan ramen

# %%
upd_menu_data.duplicated().mean()
# Out:
# 0.0

# %%
# Out:
# 0.0

# %%
final_menu_data = upd_menu_data.drop(0)
final_menu_data.head()
# Out:
#                            item    category  \
# 1                       edamame  appetizers
# 2                   house salad  appetizers
# 3       cucumber sunomono salad  appetizers
# 4  hiyashi wakame seaweed salad  appetizers
# 5                 agedashi tofu  appetizers
#
#                                          description price cost
# 1                   boiled soybeans, maldon sea salt     4    1
# 2  mixed greens, cherry tomatoes, cucumber, house...     4    2
# 3  cucumber, ponzu dressing, pickled ginger sprou...     5    2
# 4  sweet soy-marinated wakame seaweed threads, pi...     5    2
# 5  tempura battered tofu, katsuobushi, tsuyu brot...     5    2

# %%
final_sales_data = upd_sales_data.drop(0)
final_sales_data.head()
# Out:
#   Line_Item_ID        Date Credit_Card_Number Quantity             Menu_Item
# 1            1  01-01-2017   7437926611570799        1      spicy miso ramen
# 2            2  01-01-2017   7437926611570799        1      spicy miso ramen
# 3            3  01-01-2017   8421920068932819        3     tori paitan ramen
# 4            4  01-01-2017   8421920068932819        3     tori paitan ramen
# 5            5  01-01-2017   4787310681569648        1  truffle butter ramen

# %%
final_sales_data.set_index('Credit_Card_Number')
final_sales_data.head()
# Out:
#   Line_Item_ID        Date Credit_Card_Number Quantity             Menu_Item
# 1            1  01-01-2017   7437926611570799        1      spicy miso ramen
# 2            2  01-01-2017   7437926611570799        1      spicy miso ramen
# 3            3  01-01-2017   8421920068932819        3     tori paitan ramen
# 4            4  01-01-2017   8421920068932819        3     tori paitan ramen
# 5            5  01-01-2017   4787310681569648        1  truffle butter ramen

# %%
final_menu_data.set_index('item')
final_menu_data.sample(10)
# Out:
#                                               item    category  \
# 26                                       green tea      drinks
# 21                               tori paitan ramen      entree
# 24  vegetarian curry + king trumpet mushroom ramen      entree
# 23                     burnt garlic tonkotsu ramen      entree
# 12                             rock shrimp tempura  appetizers
# 3                          cucumber sunomono salad  appetizers
# 19                                 miso crab ramen      entree
# 31                      strawberry mochi ice cream    desserts
# 20                      soft-shell miso crab ramen      entree
# 27                                            coke      drinks
#
#                                           description price cost
# 26                                          green tea   2.5    1
# 21  rich, shoyu seasoned double stock (organic chi...    13    6
# 24  house curry blend + vegan dashi; fried king tr...    13    7
# ...

# %%
final_sales_data.duplicated()
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 74120    False
# 74121    False
# 74122    False
# 74123    False
# 74124    False
# Length: 74124, dtype: bool

# %%
rem_sales_data =final_sales_data.drop_duplicates(['Credit_Card_Number'])
rem_sales_data.head()
# Out:
#   Line_Item_ID        Date Credit_Card_Number Quantity              Menu_Item
# 1            1  01-01-2017   7437926611570799        1       spicy miso ramen
# 3            3  01-01-2017   8421920068932819        3      tori paitan ramen
# 5            5  01-01-2017   4787310681569648        1   truffle butter ramen
# 7            7  01-01-2017   8252818705821725        1         tonkotsu ramen
# 9            9  01-01-2017   3119034881407323        1  vegetarian spicy miso

# %%
rem_menu_data = final_menu_data.drop_duplicates(['item'])
rem_menu_data.head()
# Out:
#                            item    category  \
# 1                       edamame  appetizers
# 2                   house salad  appetizers
# 3       cucumber sunomono salad  appetizers
# 4  hiyashi wakame seaweed salad  appetizers
# 5                 agedashi tofu  appetizers
#
#                                          description price cost
# 1                   boiled soybeans, maldon sea salt     4    1
# 2  mixed greens, cherry tomatoes, cucumber, house...     4    2
# 3  cucumber, ponzu dressing, pickled ginger sprou...     5    2
# 4  sweet soy-marinated wakame seaweed threads, pi...     5    2
# 5  tempura battered tofu, katsuobushi, tsuyu brot...     5    2

# %%
combined_data_rows = pd.concat([rem_menu_data,rem_sales_data], axis="columns",join="inner")
combined_data_rows.head()
# Out:
#                           item    category  \
# 1                      edamame  appetizers
# 3      cucumber sunomono salad  appetizers
# 5                agedashi tofu  appetizers
# 7               pork floss bao  appetizers
# 9  edamame fried gyoza (vegan)  appetizers
#
#                                          description price cost Line_Item_ID  \
# 1                   boiled soybeans, maldon sea salt     4    1            1
# 3  cucumber, ponzu dressing, pickled ginger sprou...     5    2            3
# 5  tempura battered tofu, katsuobushi, tsuyu brot...     5    2            5
# 7  two steamed buns, minced lean slow braised nim...     4    2            7
# 9  six crispy fried edamame and cabbage pot stick...     6    3            9
#
#          Date Credit_Card_Number Quantity              Menu_Item
# 1  01-01-2017   7437926611570799        1       spicy miso ramen
# 3  01-01-2017   8421920068932819        3      tori paitan ramen
# ...

# %%
final_data =combined_data_rows.drop(columns =['Line_Item_ID'])
final_data.head()
# Out:
#                           item    category  \
# 1                      edamame  appetizers
# 3      cucumber sunomono salad  appetizers
# 5                agedashi tofu  appetizers
# 7               pork floss bao  appetizers
# 9  edamame fried gyoza (vegan)  appetizers
#
#                                          description price cost        Date  \
# 1                   boiled soybeans, maldon sea salt     4    1  01-01-2017
# 3  cucumber, ponzu dressing, pickled ginger sprou...     5    2  01-01-2017
# 5  tempura battered tofu, katsuobushi, tsuyu brot...     5    2  01-01-2017
# 7  two steamed buns, minced lean slow braised nim...     4    2  01-01-2017
# 9  six crispy fried edamame and cabbage pot stick...     6    3  01-01-2017
#
#   Credit_Card_Number Quantity              Menu_Item
# 1   7437926611570799        1       spicy miso ramen
# 3   8421920068932819        3      tori paitan ramen
# 5   4787310681569648        1   truffle butter ramen
# ...

# %%
new_comb_data["price"]=new_comb_data["price"].astype("int64")
new_comb_data["cost"]=new_comb_data["cost"].astype("int64")
new_comb_data.dtypes
# Out:
# item                  string
# category              string
# description           string
# price                  int64
# cost                   int64
# Date                  string
# Credit_Card_Number    string
# Quantity              string
# Menu_Item             string
# dtype: object

# %%
profit = new_comb_data["price"]- new_comb_data["cost"]
new_comb_data['profit']=profit
new_comb_data
# Out:
#                            item    category  \
# 1                       edamame  appetizers
# 3       cucumber sunomono salad  appetizers
# 5                 agedashi tofu  appetizers
# 7                pork floss bao  appetizers
# 9   edamame fried gyoza (vegan)  appetizers
# 11                     takoyaki  appetizers
# 13      soft-shell crab tempura  appetizers
# 15                 nagomi shoyu      entree
# 17             spicy miso ramen      entree
# 19              miso crab ramen      entree
# 21            tori paitan ramen      entree
# 23  burnt garlic tonkotsu ramen      entree
# 25         truffle butter ramen      entree
# 27                         coke      drinks
# 29             matcha ice cream    desserts
# 31   strawberry mochi ice cream    desserts
#
#                                           description  price  cost  \
# 1                    boiled soybeans, maldon sea salt      4     1
# 3   cucumber, ponzu dressing, pickled ginger sprou...      5     2
# ...
