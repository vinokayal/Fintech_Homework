# %%
import pandas as pd
import numpy as np
from pathlib import Path
# %matplotlib inline

# %%
# Uploading CSV files from the location
aapl_upload = Path("C:\\Users\\vinot\\Fintech_Homeworks\\HW03_Pandas\\aapl_historical.csv")
algo_upload = Path("C:\\Users\\vinot\\Fintech_Homeworks\\HW03_Pandas\\algo_returns.csv")
cost_upload = Path("C:\\Users\\vinot\\Fintech_Homeworks\\HW03_Pandas\\cost_historical.csv")
goog_upload = Path("C:\\Users\\vinot\\Fintech_Homeworks\\HW03_Pandas\\goog_historical.csv")
sp500_upload=Path("C:\\Users\\vinot\\Fintech_Homeworks\\HW03_Pandas\\sp500_history.csv")
whale_upload=Path("C:\\Users\\vinot\\Fintech_Homeworks\\HW03_Pandas\\whale_returns.csv")

# %%
#Reading the uploaded CSV files
appl_data=pd.read_csv(aapl_upload,index_col="Trade DATE",parse_dates=True,infer_datetime_format=True)
algo_data=pd.read_csv(algo_upload,index_col="Date",parse_dates=True,infer_datetime_format=True)
cost_data=pd.read_csv(cost_upload,index_col="Trade DATE",parse_dates=True,infer_datetime_format=True)
goog_data=pd.read_csv(goog_upload,index_col="Trade DATE",parse_dates=True,infer_datetime_format=True)
whale_data=pd.read_csv(whale_upload,index_col="Date",parse_dates=True,infer_datetime_format=True)
sp500_data=pd.read_csv(sp500_upload,index_col="Date",parse_dates=True,infer_datetime_format=True)

# %%
sp500_upd=sp500_data.sort_values("Date",ascending=True)
appl_upd=appl_data.sort_values("Date",ascending=True)
algo_upd=algo_data.sort_values("Date",ascending=True)
cost_upd=cost_data.sort_values("Date",ascending=True)
goog_upd=goog_data.sort_values("Date",ascending=True)
whale_upd=whale_data.sort_values("Date",ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-ccfa0507f26b> in <module>
#       1 sp500_upd=sp500_data.sort_values("Date",ascending=True)
# ----> 2 appl_upd=appl_data.sort_values("Date",ascending=True)
#       3 algo_upd=algo_data.sort_values("Date",ascending=True)
#       4 cost_upd=cost_data.sort_values("Date",ascending=True)
#       5 goog_upd=goog_data.sort_values("Date",ascending=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
# ...

# %%
#sampling header data from whale returns
whale_upd.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fb100de5ffcf> in <module>
#       1 #sampling header data from whale returns
# ----> 2 whale_upd.head()
#
# NameError: name 'whale_upd' is not defined

# %%
#Check for the Null values & count Null values
whale_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
#Drop the Null values in Whale_Data
whale_data.dropna(inplace=True)
whale_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
#Check for the Null values & count Null values
algo_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
#Check for the Null values & count Null values
algo_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
algo_data.dropna(inplace=True)
algo_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
#check the data types in sp500
sp500_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_data['Close'] = sp500_data['Close'].str.replace(r'\D', '').astype('float64')

# %%
sp500_upd=sp500_data.sort_values("Date",ascending=True)

# %%
sp500_returns=sp500_upd.pct_change()
sp500_returns
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
sp500_returns=sp500_returns.rename(columns={"Close":"S&P 500"})

# %%
sp500_returns.isnull().sum()
sp500_returns.dropna(inplace=True)
sp500_returns.isnull().sum()
# Out:
# S&P 500    0
# dtype: int64

# %%
sp500_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
algo_data.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
combined_df=pd.concat([whale_data,algo_data,sp500_returns],axis="columns",join="inner")
combined_df.dropna(inplace=True)
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %%
combined_df.plot(figsize=(30,15), title="Daily Returns")

# %%
daily_returns = combined_df.pct_change()
daily_returns.head(80)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                  -2.762070           -1.650792
# 2015-03-05                   0.800968            0.257544
# 2015-03-06                  -2.968465           -1.876837
# 2015-03-09                  -1.073656           -2.182252
# ...                               ...                 ...
# 2015-06-18                  -3.255975           -3.059570
# 2015-06-19                  -1.465048           -1.189338
# 2015-06-22                  -4.503358           -3.635412
# 2015-06-23                  -0.861689           -0.499307
# 2015-06-24                  -7.531808           -4.853319
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC     Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN        NaN
# 2015-03-04                     4.113646               -1.641381   3.422374
# ...

# %%
daily_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      14
# PAULSON & CO.INC.              14
# TIGER GLOBAL MANAGEMENT LLC    14
# BERKSHIRE HATHAWAY INC         14
# Algo 1                          1
# Algo 2                          1
# S&P 500                         1
# dtype: int64

# %%
daily_returns.dropna(inplace=True)
daily_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P 500                        0
# dtype: int64

# %%
daily_returns.plot(figsize=(10,5))

# %%
cumulative_returns = (1+ combined_df).cumprod()
cumulative_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2   S&P 500
# Date
# 2015-03-03  0.999051  0.995461
# 2015-03-04  1.001464  0.991093
# 2015-03-05  1.005794  0.992278
# ...

# %%
cumulative_returns.plot(figsize=(30,15), title="Cumulative Returns")

# %%
annualized_std=daily_std*np.sqrt(252)
annualized_std.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-49032e4f5950> in <module>
# ----> 1 annualized_std=daily_std*np.sqrt(252)
#       2 annualized_std.head()
#
# NameError: name 'daily_std' is not defined

# %%
combined_df.plot.box(figsize=(30,15))

# %%
daily_std = combined_df.std()
daily_std.head(7)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
annualized_std=daily_std*np.sqrt(252)
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# dtype: float64

# %%
all_portfolio_std=combined_df.std()
all_portfolio_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# dtype: float64

# %%
sor_value =combined_df['SOROS FUND MANAGEMENT LLC'].sum()
tiger =combined_df['TIGER GLOBAL MANAGEMENT LLC'].sum()

#combined_df['SOROS FUND MANAGEMENT LLC']>combined_df['S&P 500']

# %%
sp500 =combined_df['S&P 500'].sum()
sp500
# Out:
# 0.36432911223043807

# %%
sor_value > sp500
# Out:
# False

# %%
tiger>sp500
# Out:
# False

# %%
portfolio_a_std=np.random.normal(scale=0.25,size=10000)

# %%
combined_df.rolling(window=21).std().plot(figsize=(30,15), title="21 Day Rolling Standard Deviation")

# %%
correlation=combined_df.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
covariance = combined_df['BERKSHIRE HATHAWAY INC'].cov(combined_df['S&P 500'])
covariance
# Out:
# 8.302834941861692e-05

# %%
variance = combined_df['S&P 500'].var()
variance
# Out:
# 7.316632424648704e-05

# %%
Berk_beta = covariance/variance
Berk_beta
# Out:
# 1.1347891297491741

# %%
rolling_covariance = combined_df['BERKSHIRE HATHAWAY INC'].rolling(window=21).cov(combined_df['S&P 500'])

# %%
rolling_variance = combined_df['S&P 500'].rolling(window=21).var()

# %%
rolling_beta = rolling_covariance/rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 21-Day Beta of BERKSHIRE')

# %%
daily_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      14
# PAULSON & CO.INC.              14
# TIGER GLOBAL MANAGEMENT LLC    14
# BERKSHIRE HATHAWAY INC         14
# Algo 1                          1
# Algo 2                          1
# S&P 500                         1
# dtype: int64

# %%
daily_returns.dropna(inplace=True)

# %%
daily_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P 500                        0
# dtype: int64

# %%
rolling_covariance = daily_returns['BERKSHIRE HATHAWAY INC'].rolling(window=30).cov(daily_returns['S&P 500'])

# %%
rolling_variance = daily_returns['S&P 500'].rolling(window=30).var()

# %%
rolling_beta = rolling_covariance/rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 21-Day Beta of BERKSHIRE')

# %%
covariance = daily_returns['BERKSHIRE HATHAWAY INC'].cov(daily_returns['S&P 500'])
covariance
# Out:
# nan
